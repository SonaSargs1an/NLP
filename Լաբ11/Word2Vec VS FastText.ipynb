# %%
pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 91.4 MB/s eta 0:00:00
# ...

# %%
import nltk
from gensim.models import Word2Vec
from nltk.corpus import brown
import numpy as np

nltk.download('brown')
data = brown.sents()

print(f"Training on {len(data)} sentences...")

w2v_model = Word2Vec(
    sentences = data,
    sg=1,
    vector_size=100,
    window=5,
    min_count=1,
    epochs = 10
)

w2v_model.save("brown_w2v.model")
print("\nModel saved as 'brown_w2v.model'")
print(w2v_model.wv.index_to_key)
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# Training on 57340 sentences...
#
# Model saved as 'brown_w2v.model'
# ...

# %%
from gensim.models import FastText

nltk.download('brown')

data = brown.sents()
print(f"Training FastText on {len(data)} sentences...")

ft_model = FastText(
    sentences = data,
    sg=1,
    vector_size=100,
    window=5,
    min_count=1,
    min_n=3,
    max_n=6,
    epochs = 10
)
ft_model.save("brown_fasttext.model")
print(ft_model.wv.index_to_key)
print("Model saved as 'brown_fasttext.model'")
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# Training FastText on 57340 sentences...
# ...

# %%
from gensim.models import Word2Vec, FastText

# --- TEST 1: Word2Vec ---

test_word = "good"
print("1. Word2Vec:")
w2v_model = Word2Vec.load("brown_w2v.model")
ft_model = FastText.load("brown_fasttext.model")
print(w2v_model.wv.index_to_key)

try:
    vector = w2v_model.wv[test_word]
    print("   Success! Vector found.")
except KeyError:
    print(f"   FAILED. Word2Vec does not know '{test_word}'.")

# --- TEST 2: FastText ---
print("\n2. FastText:")
try:
    # FastText constructs a vector on the fly
    vector = ft_model.wv[test_word]
    print("   Success! Vector generated.")

    # Let's see what it thinks 'smartphone' is related to
    # It usually finds words with similar SPELLING or ROOTS
    similar = ft_model.wv.most_similar(test_word, topn=3)
    print(f"   Most similar words in 1961 context: {similar}")

except KeyError:
    print("   FAILED.")
# Out:
# 1. Word2Vec:
# ...

# %%
#Experement 2
from gensim.models import Word2Vec, FastText

w2v_model = Word2Vec.load("brown_w2v.model")
ft_model = FastText.load("brown_fasttext.model")

# --- 2. Define the Test Pairs ---
pairs = [
    ('unteachable', 'teacher'),
    ('recomputation', 'computation'),
    ('unnaturalness', 'natural')
]

print(f"\n{'Pair':<30} | {'Word2Vec Score':<15} | {'FastText Score':<15}")
print("-" * 65)

# --- 3. Calculate Similarities ---
for rare, common in pairs:
    # --- Check Word2Vec ---
    try:
        w2v_score = w2v_model.wv.similarity(rare, common)
        w2v_result = f"{w2v_score:.4f}"
    except KeyError:
        # This happens if min_count filtered the rare word out
        w2v_result = "OOV (Missing)"

    # --- Check FastText ---
    try:
        ft_score = ft_model.wv.similarity(rare, common)
        ft_result = f"{ft_score:.4f}"
    except KeyError:
        ft_result = "Error"

    print(f"{rare} / {common:<12} | {w2v_result:<15} | {ft_result:<15}")
# Out:
# Pair                           | Word2Vec Score  | FastText Score
# -----------------------------------------------------------------
# unteachable / teacher      | OOV (Missing)   | 0.6599
# recomputation / computation  | OOV (Missing)   | 0.9710
# unnaturalness / natural      | 0.5504          | 0.8457

# %%
#Experement 3
from gensim.models import Word2Vec, FastText
w2v_model = Word2Vec.load("brown_w2v.model")
ft_model = FastText.load("brown_fasttext.model")

target_words = ['teaching', 'computation']
# --- Word2Vec Results ---
for word in target_words:
  try:
    w2v_sim = w2v_model.wv.most_similar(word, topn=5)
    for similar, score in w2v_sim:
      print(f"{similar:<20} {score:.4f}")
  except KeyError:
    print(f"Word2Vec does not know '{word}'.")
# --- FastText Results ---
try:
  ft_sim = ft_model.wv.most_similar(word, topn=5)
  for similar, score in ft_sim:
    print(f"{similar:<20} {score:.4f}")
except KeyError:
  print(f"Word '{word}' not in FastText vocabulary.")
# Out:
# quest                0.8500
# qualifications       0.8406
# selecting            0.8395
# country's            0.8387
# self-discipline      0.8382
# reimburses           0.9478
# underwriting         0.9434
# BTU's                0.9423
# subcontracting       0.9410
# waived               0.9403
# co-optation          0.9651
# compilation          0.9645
# constatation         0.9537
# commutation          0.9533
# dilatation           0.9527

# %%
#Experement 4
from gensim.models import Word2Vec, FastText

print("Loading models...")
w2v_model = Word2Vec.load("brown_w2v.model")
ft_model = FastText.load("brown_fasttext.model")

# --- 2. Define the Analogies ---
# Format: (positive_b, negative_a, positive_c, expected_d)
# Logic: b - a + c = d
analogies = [
    # teacher : teaching :: computer : ?
    ('teaching', 'teacher', 'computer', 'computing'),

    # natural : naturally :: quick : ?
    ('naturally', 'natural', 'quick', 'quickly')
]

print(f"\n{'Expected':<15} | {'Word2Vec Prediction':<20} | {'FastText Prediction':<20}")
print("-" * 65)

# --- 3. Run the Math ---
for pos_b, neg_a, pos_c, expected in analogies:

    # --- Word2Vec ---
    try:
        # positive=[b, c], negative=[a]
        w2v_res = w2v_model.wv.most_similar(
            positive=[pos_b, pos_c],
            negative=[neg_a],
            topn=1
        )
        w2v_pred = f"{w2v_res[0][0]} ({w2v_res[0][1]:.2f})"
    except KeyError:
        w2v_pred = "OOV Error"

    # --- FastText ---
    try:
        ft_res = ft_model.wv.most_similar(
            positive=[pos_b, pos_c],
            negative=[neg_a],
            topn=1
        )
        ft_pred = f"{ft_res[0][0]} ({ft_res[0][1]:.2f})"
    except KeyError:
        ft_pred = "OOV Error"

    print(f"{expected:<15} | {w2v_pred:<20} | {ft_pred:<20}")
# Out:
# Loading models...
#
# Expected        | Word2Vec Prediction  | FastText Prediction
# -----------------------------------------------------------------
# computing       | manifold (0.85)      | computing (0.86)
# quickly         | Trig (0.70)          | quickly (0.87)
